# %%
import whisper

import requests 
from bs4 import BeautifulSoup 

import json
import os

# %%
from youtube_dl import YoutubeDL

# %%
audio_downloader = YoutubeDL({'format':'bestaudio'})

audio_downloader.extract_info('https://www.youtube.com/watch?v=3S4cNfl0YF0&list=PL9B24A6A9D5754E70&index=1')
# Out:
# [youtube:tab] Downloading playlist PL9B24A6A9D5754E70 - add --no-playlist to just download video 3S4cNfl0YF0
# [youtube:tab] PL9B24A6A9D5754E70: Downloading webpage
# [youtube:tab] PL9B24A6A9D5754E70: Downloading webpage
# [download] Downloading playlist: MIT 6.01SC Introduction to EECS I
# [youtube:tab] playlist MIT 6.01SC Introduction to EECS I: Downloading 27 videos
# [download] Downloading video 1 of 27
# [youtube] 3S4cNfl0YF0: Downloading webpage
# [download] Destination: Lec 1 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-3S4cNfl0YF0.m4a
# [download] 100% of 71.84MiB in 19:1863KiB/s ETA 00:00101
# [ffmpeg] Correcting container in "Lec 1 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-3S4cNfl0YF0.m4a"
# [download] Downloading video 2 of 27
# [youtube] hdjWA3YcDII: Downloading webpage
# [download] Destination: Rec 1 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-hdjWA3YcDII.m4a
# [download] 100% of 10.53MiB in 02:4125KiB/s ETA 00:005
# [ffmpeg] Correcting container in "Rec 1 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-hdjWA3YcDII.m4a"
# [download] Downloading video 3 of 27
# [youtube] abW4cppRABM: Downloading webpage
# [download] Destination: Rec 2 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-abW4cppRABM.m4a
# [download] 100% of 12.43MiB in 04:3894KiB/s ETA 00:00
# [ffmpeg] Correcting container in "Rec 2 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-abW4cppRABM.m4a"
# [download] Downloading video 4 of 27
# [youtube] cQntMUMQyRw: Downloading webpage
# [download] Destination: Lec 2 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-cQntMUMQyRw.m4a
# [download] 100% of 72.83MiB in 24:2475KiB/s ETA 00:00:08
# [ffmpeg] Correcting container in "Lec 2 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-cQntMUMQyRw.m4a"
# [download] Downloading video 5 of 27
# [youtube] Y9r9dO7KQj4: Downloading webpage
# [download] Destination: Rec 3 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-Y9r9dO7KQj4.m4a
# [download] 100% of 15.25MiB in 04:0567KiB/s ETA 00:001
# [ffmpeg] Correcting container in "Rec 3 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-Y9r9dO7KQj4.m4a"
# [download] Downloading video 6 of 27
# [youtube] 8FWfmvj3HYw: Downloading webpage
# [download] Destination: Rec 4 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-8FWfmvj3HYw.m4a
# [download] 100% of 12.66MiB in 03:1076KiB/s ETA 00:006
# [ffmpeg] Correcting container in "Rec 4 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-8FWfmvj3HYw.m4a"
# [download] Downloading video 7 of 27
# [youtube] CG4ihzTaGdM: Downloading webpage
# [download] Destination: Lec 3 _ MIT 6.01SC Introduction to Electrical Engineering and Computer Science I, Spring 2011-CG4ihzTaGdM.m4a
# [download]   5.4% of 73.82MiB at 68.86KiB/s ETA 17:18834
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/07/58sc206x78d9p6tm35y898h00000gn/T/ipykernel_46430/2185007993.py in <module>
#       1 audio_downloader = YoutubeDL({'format':'bestaudio'})
#       2
# ----> 3 audio_downloader.extract_info('https://www.youtube.com/watch?v=3S4cNfl0YF0&list=PL9B24A6A9D5754E70&index=1')
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#     806                                     'and will probably not work.')
#     807
# --> 808             return self.__extract_info(url, ie, download, extra_info, process)
#     809         else:
#     810             self.report_error('no suitable InfoExtractor for URL %s' % url)
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in wrapper(self, *args, **kwargs)
#     813         def wrapper(self, *args, **kwargs):
#     814             try:
# --> 815                 return func(self, *args, **kwargs)
#     816             except GeoRestrictedError as e:
#     817                 msg = e.msg
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#     845         self.add_default_extra_info(ie_result, ie, url)
#     846         if process:
# --> 847             return self.process_ie_result(ie_result, download, extra_info)
#     848         else:
#     849             return ie_result
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#     883             # We have to add extra_info to the results because it may be
#     884             # contained in a playlist
# --> 885             return self.extract_info(ie_result['url'],
#     886                                      download,
#     887                                      ie_key=ie_result.get('ie_key'),
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#     806                                     'and will probably not work.')
#     807
# --> 808             return self.__extract_info(url, ie, download, extra_info, process)
#     809         else:
#     810             self.report_error('no suitable InfoExtractor for URL %s' % url)
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in wrapper(self, *args, **kwargs)
#     813         def wrapper(self, *args, **kwargs):
#     814             try:
# --> 815                 return func(self, *args, **kwargs)
#     816             except GeoRestrictedError as e:
#     817                 msg = e.msg
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#     845         self.add_default_extra_info(ie_result, ie, url)
#     846         if process:
# --> 847             return self.process_ie_result(ie_result, download, extra_info)
#     848         else:
#     849             return ie_result
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#     931             self._playlist_urls.add(webpage_url)
#     932             try:
# --> 933                 return self.__process_playlist(ie_result, download)
#     934             finally:
#     935                 self._playlist_level -= 1
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in __process_playlist(self, ie_result, download)
#    1065                 continue
#    1066
# -> 1067             entry_result = self.__process_iterable_entry(entry, download, extra)
#    1068             # TODO: skip failed (empty) entries?
#    1069             playlist_results.append(entry_result)
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in wrapper(self, *args, **kwargs)
#     813         def wrapper(self, *args, **kwargs):
#     814             try:
# --> 815                 return func(self, *args, **kwargs)
#     816             except GeoRestrictedError as e:
#     817                 msg = e.msg
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in __process_iterable_entry(self, entry, download, extra_info)
#    1074     @__handle_extraction_exceptions
#    1075     def __process_iterable_entry(self, entry, download, extra_info):
# -> 1076         return self.process_ie_result(
#    1077             entry, download=download, extra_info=extra_info)
#    1078
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#     883             # We have to add extra_info to the results because it may be
#     884             # contained in a playlist
# --> 885             return self.extract_info(ie_result['url'],
#     886                                      download,
#     887                                      ie_key=ie_result.get('ie_key'),
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#     806                                     'and will probably not work.')
#     807
# --> 808             return self.__extract_info(url, ie, download, extra_info, process)
#     809         else:
#     810             self.report_error('no suitable InfoExtractor for URL %s' % url)
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in wrapper(self, *args, **kwargs)
#     813         def wrapper(self, *args, **kwargs):
#     814             try:
# --> 815                 return func(self, *args, **kwargs)
#     816             except GeoRestrictedError as e:
#     817                 msg = e.msg
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#     845         self.add_default_extra_info(ie_result, ie, url)
#     846         if process:
# --> 847             return self.process_ie_result(ie_result, download, extra_info)
#     848         else:
#     849             return ie_result
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#     879         if result_type == 'video':
#     880             self.add_extra_info(ie_result, extra_info)
# --> 881             return self.process_video_result(ie_result, download=download)
#     882         elif result_type == 'url':
#     883             # We have to add extra_info to the results because it may be
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in process_video_result(self, info_dict, download)
#    1690                 new_info = dict(info_dict)
#    1691                 new_info.update(format)
# -> 1692                 self.process_info(new_info)
#    1693         # We update the info dict with the best quality format (backwards compatibility)
#    1694         info_dict.update(formats_to_download[-1])
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in process_info(self, info_dict)
#    1974                 else:
#    1975                     # Just a single file
# -> 1976                     success = dl(filename, info_dict)
#    1977             except (compat_urllib_error.URLError, compat_http_client.HTTPException, socket.error) as err:
#    1978                 self.report_error('unable to download video data: %s' % error_to_compat_str(err))
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in dl(name, info)
#    1913                     if self.params.get('verbose'):
#    1914                         self.to_screen('[debug] Invoking downloader on %r' % info.get('url'))
# -> 1915                     return fd.download(name, info)
#    1916
#    1917                 if info_dict.get('requested_formats') is not None:
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/downloader/common.py in download(self, filename, info_dict)
#     364             time.sleep(sleep_interval)
#     365
# --> 366         return self.real_download(filename, info_dict)
#     367
#     368     def real_download(self, filename, info_dict):
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/downloader/http.py in real_download(self, filename, info_dict)
#     350             try:
#     351                 establish_connection()
# --> 352                 return download()
#     353             except RetryDownload as e:
#     354                 count += 1
#
# ~/miniconda3/lib/python3.8/site-packages/youtube_dl/downloader/http.py in download()
#     236                 try:
#     237                     # Download and write
# --> 238                     data_block = ctx.data.read(block_size if data_len is None else min(block_size, data_len - byte_counter))
#     239                 # socket.timeout is a subclass of socket.error but may not have
#     240                 # errno set
#
# ~/miniconda3/lib/python3.8/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# ~/miniconda3/lib/python3.8/http/client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/miniconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/miniconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/miniconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# assigning srt variable with the list
# of dictionaries obtained by the get_transcript() function
srt = YouTubeTranscriptApi.get_transcript("3S4cNfl0YF0")

# prints the result
print(srt)
# Out:
# [{'text': 'The following content is\nprovided under a Creative', 'start': 0.53, 'duration': 2.43}, {'text': 'Commons license.', 'start': 2.96, 'duration': 1.41}, {'text': 'Your support will help MIT\nOpenCourseWare continue to', 'start': 4.37, 'duration': 3.04}, {'text': 'offer high quality educational\nresources for free.', 'start': 7.41, 'duration': 3.65}, {'text': 'To make a donation or view\nadditional materials from', 'start': 11.06, 'duration': 2.9}, {'text': 'hundreds of MIT courses, visit\nMIT OpenCourseWare at', 'start': 13.96, 'duration': 3.93}, {'text': 'ocw.mit.edu.', 'start': 17.89, 'duration': 1.25}, {'text': 'PROFESSOR: Hello, and\nwelcome to 6.01.', 'start': 28.48, 'duration': 3.12}, {'text': "I'm Denny Freeman.", 'start': 31.6, 'duration': 0.809}, {'text': "I'm the lecturer.", 'start': 32.409, 'duration': 1.521}, {'text': "One thing you should know about\ntoday is that there's a", 'start': 33.93, 'duration': 2.04}, {'text': 'single hand-out.', 'start': 35.97, 'duration': 1.09}, {'text': 'You should have picked\nit up on your way in.', 'start': 37.06, 'duration': 1.77}, {'text': "It's available at either\nof the two doors.", 'start': 38.83, 'duration': 1.54}, {'text': 'What I want to do today in this\nfirst lecture is mostly', 'start': 42.98, 'duration': 4.67}, {'text': 'focus on content.', 'start': 47.65, 'duration': 3.1}, {'text': 'But before I do that, since\n6.01 is a little bit of an', 'start': 50.75, 'duration': 3.28}, {'text': 'unusual course, I want to give\nyou a little bit of an', 'start': 54.03, 'duration': 2.29}, {'text': 'overview and tell you a little\nbit about the administration', 'start': 56.32, 'duration': 2.69}, {'text': 'of the course.', 'start': 59.01, 'duration': 1.25}, {'text': '6.01 is mostly about\nmodes of reasoning.', 'start': 63.02, 'duration': 8.47}, {'text': 'What we would like you to get\nout of this course is ways to', 'start': 71.49, 'duration': 2.92}, {'text': 'think about engineering.', 'start': 74.41, 'duration': 3.39}, {'text': 'We want to talk about how do you\ndesign, how do you build,', 'start': 77.8, 'duration': 3.53}, {'text': 'how do you construct, how do you\ndebug complicated systems?', 'start': 81.33, 'duration': 4.7}, {'text': "That's what engineers do, and\nwe're very good at it.", 'start': 86.03, 'duration': 4.64}, {'text': 'And we want to make you\nvery good at it.', 'start': 90.67, 'duration': 3.03}, {'text': "We're very good at it.", 'start': 93.7, 'duration': 1.08}, {'text': 'And you know that from your\ncommon, everyday experience.', 'start': 94.78, 'duration': 2.81}, {'text': 'Laptops are incredible.', 'start': 97.59, 'duration': 3.42}, {'text': "As we go through the course,\nyou're going to see that", 'start': 101.01, 'duration': 2.98}, {'text': 'laptops incorporate things\nfrom the tiniest, tiniest', 'start': 103.99, 'duration': 3.22}, {'text': "level, things so small that\nyou can't see them.", 'start': 107.21, 'duration': 4.34}, {'text': "They're microscopic.", 'start': 111.55, 'duration': 0.82}, {'text': 'The individual transistors are\nnot things that you can see.', 'start': 112.37, 'duration': 3.23}, {'text': 'We develop special tools for\nyou even to be able to', 'start': 115.6, 'duration': 2.56}, {'text': 'visualize them.', 'start': 118.16, 'duration': 2.36}, {'text': 'And yet, we conglomerate\nbillions of them into a system', 'start': 120.52, 'duration': 3.84}, {'text': 'that works relatively\nreliably.', 'start': 124.36, 'duration': 2.07}, {'text': "Now, I realize I'm going out on\na limb because when you say", 'start': 126.43, 'duration': 3.15}, {'text': 'things like that, then\nthings always fail.', 'start': 129.58, 'duration': 1.835}, {'text': "But I'll go out on a limb and\nsay, for the most part, the", 'start': 131.415, 'duration': 3.835}, {'text': 'systems we construct\nare very reliable.', 'start': 135.25, 'duration': 4.02}, {'text': "We'd like you to know how you\nthink about making such a", 'start': 139.27, 'duration': 3.52}, {'text': 'c ...
